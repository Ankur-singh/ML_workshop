# %% [markdown]
# # Student clustering
#
# Every child is not the same. They all have different requirements, different ways of learning and speed. So I don't single study pattern for all the different student is correct. Its a very important job to identify different sets of student, understand their differences and respect them.
#
# For a human it might be a difficult task if the number of student are more. Machine Learning is at your rescue!

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
# %matplotlib notebook

# %% [markdown]
# ##  Load and Plotting Data

# %%
data = pd.read_csv('Datasets/student-por.csv',sep = ';')
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
# school        649 non-null object
# sex           649 non-null object
# age           649 non-null int64
# address       649 non-null object
# famsize       649 non-null object
# Pstatus       649 non-null object
# Medu          649 non-null int64
# Fedu          649 non-null int64
# Mjob          649 non-null object
# Fjob          649 non-null object
# reason        649 non-null object
# guardian      649 non-null object
# traveltime    649 non-null int64
# studytime     649 non-null int64
# failures      649 non-null int64
# schoolsup     649 non-null object
# famsup        649 non-null object
# paid          649 non-null object
# activities    649 non-null object
# nursery       649 non-null object
# higher        649 non-null object
# internet      649 non-null object
# romantic      649 non-null object
# famrel        649 non-null int64
# ...

# %%
data.shape
# Out:
# (649, 33)

# %% [markdown]
# ##  Data Preprocessing

# %%
data1=pd.get_dummies(data,drop_first = True)
data1.head()
# Out:
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         0       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc      ...       guardian_mother  guardian_other  schoolsup_yes  \
# 0     1      ...                     1               0              1
# 1     1      ...                     0               0              0
# 2     2      ...                     1               0              1
# 3     1      ...                     1               0              0
# 4     1      ...                     0               0              0
#
#    famsup_yes  paid_yes  activities_yes  nursery_yes  higher_yes  \
# ...

# %% [markdown]
# ##  Dimesionalty Reduction

# %%
X2 = PCA(3).fit_transform(data1)
X2
# Out:
# array([[ 5.81651345, -2.82740279, -1.49574624],
#        [ 0.93985229, -2.57557155, -2.00356419],
#        [ 0.22498237,  2.48053528, -0.81037513],
#        ...,
#        [ 2.77527387,  0.88187405, -2.56707747],
#        [ 3.94549069,  0.56239787,  1.49324465],
#        [ 1.83454176, -0.60532205,  1.39092342]])

# %%
fig = plt.figure(figsize=(10,8))
ax = Axes3D(fig)
ax.scatter(X2[:, 0], X2[:, 1],X2[:,2], s=[100]*len(X2))
# Out:
# <img src="data:image/png;base64,..." width="824.1">

# %% [markdown]
# ## Unsupervised Clustering

# %%
y_pred = KMeans(n_clusters=3).fit(data1)
labels = y_pred.predict(data1)

# %%
fig = plt.figure(figsize=(10,8))
ax = Axes3D(fig)
ax.scatter(X2[:, 0], X2[:, 1],X2[:,2], s=[100]*len(X2),c=labels, cmap='rainbow')
# Out:
# <img src="data:image/png;base64,..." width="999.4166666666666">
